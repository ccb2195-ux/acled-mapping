# %%
pip install folium,
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: 'folium,': Expected end or semicolon (after name and no valid version specifier)
#     folium,
#           ^

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in c:\users\craig\appdata\roaming\python\python313\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\craig\appdata\roaming\python\python313\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_excel("ACLED_MENA_Data.xlsx")

df.head()
# Out:
#         WEEK       REGION  COUNTRY   ADMIN1                  EVENT_TYPE  \
# 0 2016-02-06  Middle East  Bahrain  Capital                     Battles
# 1 2016-06-25  Middle East  Bahrain  Capital  Explosions/Remote violence
# 2 2017-02-11  Middle East  Bahrain  Capital  Explosions/Remote violence
# 3 2017-02-18  Middle East  Bahrain  Capital  Explosions/Remote violence
# 4 2017-08-12  Middle East  Bahrain  Capital  Explosions/Remote violence
#
#                   SUB_EVENT_TYPE  EVENTS  FATALITIES  POPULATION_EXPOSURE  \
# 0                    Armed clash       1           0              69821.0
# 1  Remote explosive/landmine/IED       1           1               5568.0
# 2  Remote explosive/landmine/IED       2           0               4084.0
# 3  Remote explosive/landmine/IED       1           0               4084.0
# 4  Remote explosive/landmine/IED       1           0               4084.0
#
#         DISORDER_TYPE     ID  CENTROID_LATITUDE  CENTROID_LONGITUDE
# 0  Political violence  285.0            26.1927             50.5508
# 1  Political violence  285.0            26.1927             50.5508
# 2  Political violence  285.0            26.1927             50.5508
# 3  Political violence  285.0            26.1927             50.5508
# 4  Political violence  285.0            26.1927             50.5508

# %%
# Make sure WEEK is datetime

df["WEEK"] = pd.to_datetime(df["WEEK"])

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 142122 entries, 0 to 142121
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   WEEK                 142122 non-null  datetime64[us]
#  1   REGION               142122 non-null  str
#  2   COUNTRY              142122 non-null  str
#  3   ADMIN1               142122 non-null  str
#  4   EVENT_TYPE           142122 non-null  str
#  5   SUB_EVENT_TYPE       142122 non-null  str
#  6   EVENTS               142122 non-null  int64
#  7   FATALITIES           142122 non-null  int64
#  8   POPULATION_EXPOSURE  113277 non-null  float64
#  9   DISORDER_TYPE        142122 non-null  str
#  10  ID                   142120 non-null  float64
#  11  CENTROID_LATITUDE    142122 non-null  float64
#  12  CENTROID_LONGITUDE   142122 non-null  float64
# dtypes: datetime64[us](1), float64(4), int64(2), str(6)
# memory usage: 14.1 MB

# %%
# subsetting events by subtype == Excessive force against protestors

df_small = df[df["SUB_EVENT_TYPE"] == "Excessive force against protesters"].copy()
df_small.head()
# Out:
#          WEEK       REGION  COUNTRY   ADMIN1 EVENT_TYPE  \
# 8  2016-03-05  Middle East  Bahrain  Capital   Protests
# 9  2016-03-26  Middle East  Bahrain  Capital   Protests
# 10 2017-01-07  Middle East  Bahrain  Capital   Protests
# 11 2017-03-25  Middle East  Bahrain  Capital   Protests
# 12 2018-05-12  Middle East  Bahrain  Capital   Protests
#
#                         SUB_EVENT_TYPE  EVENTS  FATALITIES  \
# 8   Excessive force against protesters       1           0
# 9   Excessive force against protesters       2           0
# 10  Excessive force against protesters       1           0
# 11  Excessive force against protesters       1           0
# 12  Excessive force against protesters       1           0
#
#     POPULATION_EXPOSURE                       DISORDER_TYPE     ID  \
# 8                4853.0  Political violence; Demonstrations  285.0
# 9               38447.0  Political violence; Demonstrations  285.0
# 10               4744.0  Political violence; Demonstrations  285.0
# 11               7574.0  Political violence; Demonstrations  285.0
# 12               4908.0  Political violence; Demonstrations  285.0
#
#     CENTROID_LATITUDE  CENTROID_LONGITUDE
# 8             26.1927             50.5508
# 9             26.1927             50.5508
# 10            26.1927             50.5508
# 11            26.1927             50.5508
# 12            26.1927             50.5508

# %%
# Build geojson data for Folium 

import numpy as np

features = [
    {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [lon, lat],
        },
        "properties": {
            "popup": sub_event,
            "style": {
                "radius": max(3, fatalities * 1.5),
                "fillOpacity": 0.6,
            },
        },
    }
    for lon, lat, sub_event, fatalities in zip(
        df_small["CENTROID_LONGITUDE"],
        df_small["CENTROID_LATITUDE"],
        df_small["SUB_EVENT_TYPE"],
        df_small["FATALITIES"],
    )
]

# %%
# Mapping with Folium

import folium

m = folium.Map(
    location=[
        df_small["CENTROID_LATITUDE"].mean(),
        df_small["CENTROID_LONGITUDE"].mean()
    ],
    zoom_start=6,
    titles='OpenStreetMap'
)

TimestampedGeoJson(
    geojson,
    period="P1W",
    duration="P4W",
    transition_time=100,
    auto_play=False,        # 🔥 critical
    loop=False,
    add_last_point=False,
    time_slider_drag_update=True  # 🔥 critical
).add_to(m)

m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 13
#       3 import folium
#       4 m = folium.Map(
#       5     location=[
#       6         df_small["CENTROID_LATITUDE"].mean(),
#    (...)     10     titles='OpenStreetMap'
#      11 )
# ---> 13 TimestampedGeoJson(
#      14     geojson,
#      15     period="P1W",
#      16     duration="P4W",
#      17     transition_time=100,
#      18     auto_play=False,        # 🔥 critical
#      19     loop=False,
#      20     add_last_point=False,
#      21     time_slider_drag_update=True  # 🔥 critical
#      22 ).add_to(m)
#      24 m
#
# NameError: name 'TimestampedGeoJson' is not defined

# %%
m.save('ACLED_MENA_map.html')

# %%
# Map # 2
for _, row in df_small.iterrows():
    folium.CircleMarker(
        location=[row["CENTROID_LATITUDE"], row["CENTROID_LONGITUDE"]],
        radius=3,
        color="grey",
        fill=True,
        fill_opacity=0.2
    ).add_to(m)

# %%
duration="P1W",
add_last_point=False

# %%
# Build geojson data for Folium with updated popup

import folium
from folium.plugins import TimestampedGeoJson

df_small["time"] = df_small["WEEK"].dt.strftime("%Y-%m-%d")

features = [
    {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [lon, lat],
        },
        "properties": {
            "time": time,
            "popup": f"<b>{country}</b><br>{admin1}<br>{sub_event}",
            "style": {
                "radius": max(3, fatalities * 1.5),
                "fillOpacity": 0.6,
            },
        },
    }
    for lon, lat, time, sub_event, fatalities, country, admin1 in zip(
        df_small["CENTROID_LONGITUDE"],
        df_small["CENTROID_LATITUDE"],
        df_small["time"],
        df_small["SUB_EVENT_TYPE"],
        df_small["FATALITIES"],
        df_small["COUNTRY"],
        df_small["ADMIN1"],
    )
]

geojson = {"type": "FeatureCollection", "features": features}

# %%
# Create timeline density histogram with Altair
import altair as alt
import pandas as pd

# Enable the default renderer for Jupyter
alt.renderers.enable('default')

# Group by week and count events
weekly_counts = df_small.groupby('WEEK').size().reset_index(name='event_count')

# Create base bar chart
bars = alt.Chart(weekly_counts).mark_bar(
    color='#d62728',
    opacity=0.7,
    width=7
).encode(
    x=alt.X('WEEK:T', 
            title='Date',
            axis=alt.Axis(labelAngle=-45)),
    y=alt.Y('event_count:Q', 
            title='Number of Events',
            scale=alt.Scale(domain=[0, weekly_counts['event_count'].max() * 1.1]))
)

# Create annotation for Iran protests (Dec 28, 2025)
iran_protest_date = pd.to_datetime('2025-12-28')

# Vertical line annotation
rule = alt.Chart(pd.DataFrame({'date': [iran_protest_date]})).mark_rule(
    color='#0f2aa1',
    strokeWidth=2,
    strokeDash=[5, 5]
).encode(
    x='date:T'
)

# Text annotation
text = alt.Chart(pd.DataFrame({
    'date': [iran_protest_date],
    'y': [weekly_counts['event_count'].max() * 0.95],
    'label': ['Iran Protests Begin']
})).mark_text(
    align='left',
    dx=5,
    dy=-5,
    color='#0f2aa1',
    fontSize=11,
    fontWeight='bold'
).encode(
    x='date:T',
    y=alt.Y('y:Q'),
    text='label:N'
)

# Combine all layers
chart = (bars + rule + text).properties(
    width=800,
    height=250,
    title={
        "text": 'Event Density Over Time - Excessive Force Against Protesters',
        "fontSize": 14,
        "fontWeight": 'bold'
    }
).configure_axis(
    gridOpacity=0.3
)

# Display the chart
display(chart)

# Save as PNG (requires vl-convert or altair_saver)
chart.save('density_plot.png', scale_factor=2.0)

print(f"\nTotal weeks with events: {len(weekly_counts)}")
print(f"Average events per week: {weekly_counts['event_count'].mean():.1f}")
print(f"Max events in a week: {weekly_counts['event_count'].max()}")
print(f"\nChart saved as density_plot.png")

# %%
# Mapping with Folium

m = folium.Map(
    location=[
        df_small["CENTROID_LATITUDE"].mean(),
        df_small["CENTROID_LONGITUDE"].mean()
    ],
    zoom_start=5,  # Reduced from 6 to zoom out ~20%
    titles='OpenStreetMap'
)

# Add grey ghost markers first (these stay visible as background)
for _, row in df_small.iterrows():
    folium.CircleMarker(
        location=[row["CENTROID_LATITUDE"], row["CENTROID_LONGITUDE"]],
        radius=3,
        color="grey",
        fill=True,
        fillColor="grey",
        fill_opacity=0.3
    ).add_to(m)

# Add animated layer on top
TimestampedGeoJson(
    geojson,
    period="P1W",
    duration="P4W",
    transition_time=100,
    auto_play=False,        # 🔥 critical
    loop=False,
    add_last_point=False,
    time_slider_drag_update=True  # 🔥 critical
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8b756614fa3362249d4f01ca5212f40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8b756614fa3362249d4f01ca5212f40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8b756614fa3362249d4f01ca5212f40 = L.map(
#                 &quot;map_c8b756614fa3362249d4f01ca5212f40&quot;,
#                 {
#                     center: [30.13962709867452, 41.841415758468344],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;titles&quot;: &quot;OpenStreetMap&quot;,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1084f1960f8860f4498b58b44cf1f39c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1084f1960f8860f4498b58b44cf1f39c.addTo(map_c8b756614fa3362249d4f01ca5212f40);
#
#
#             var circle_marker_7237226675ef16cc3ec8907e74f9c607 = L.circleMarker(
#                 [26.1927, 50.5508],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c8b756614fa3362249d4f01ca5212f40);
#
#
#             var circle_marker_2137d20431b63a5c368f0933f74e4ef4 = L.circleMarker(
#                 [26.1927, 50.5508],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c8b756614fa3362249d4f01ca5212f40);
#
#
#             var circle_marker_62ebba1ce34cdc5b5c4689079916c940 = L.circleMarker(
#                 [26.1927, 50.5508],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c8b756614fa3362249d4f01ca5212f40);
#
#
#             var circle_marker_e169eb5971deff9b4f759474b25a3380 = L.circleMarker(
#                 [26.1927, 50.5508],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;grey&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c8b756614fa3362249d4f01ca5212f40);
#
#
#             var circle_marker_e005d9cc447053c0f978ee01e62ddaed = L.circleMarker(
#                 [26.1927, 50.5508],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;grey&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;

# %%
m.save('ACLED_MENA_Map2.html')
